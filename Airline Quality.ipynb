# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Download file

# %%
airline_q=pd.read_csv('/Users/roaa/Downloads/Airline Quality Ratings.csv')
airline_q
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %% [markdown]
# # Scan and clean data

# %%
airline_q.sample(10)
# Out:
#             ID  Gender  Age Customer Type Type of Travel     Class  \
# 95118    95119  Female   43     Returning       Personal   Economy
# 106469  106470  Female   22    First-time       Business   Economy
# 88767    88768    Male   63     Returning       Business  Business
# 6684      6685  Female   58    First-time       Business  Business
# 56010    56011    Male   49     Returning       Business  Business
# 121182  121183  Female   21     Returning       Personal   Economy
# 71113    71114    Male   16     Returning       Personal   Economy
# 46111    46112  Female   51     Returning       Personal   Economy
# 78418    78419    Male   38     Returning       Business   Economy
# 39837    39838    Male   58    First-time       Business  Business
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 95118               677                0            0.0
# 106469             1300                7            9.0
# 88767               404               13           24.0
# ...

# %%
airline_q.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
airline_q['Arrival Delay']=airline_q['Arrival Delay'].fillna(0)

# %%
airline_q.isnull().sum()
# Out:
# ID                                        0
# Gender                                    0
# Age                                       0
# Customer Type                             0
# Type of Travel                            0
# Class                                     0
# Flight Distance                           0
# Departure Delay                           0
# Arrival Delay                             0
# Departure and Arrival Time Convenience    0
# Ease of Online Booking                    0
# Check-in Service                          0
# Online Boarding                           0
# Gate Location                             0
# On-board Service                          0
# Seat Comfort                              0
# Leg Room Service                          0
# Cleanliness                               0
# Food and Drink                            0
# In-flight Service                         0
# In-flight Wifi Service                    0
# ...

# %% [markdown]
# # Data exploration

# %%
airline_q.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129880 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
airline_q['Customer Type'].value_counts()
# Out:
# Customer Type
# Returning     106100
# First-time     23780
# Name: count, dtype: int64

# %%
airline_q['Gender'].value_counts()
# Out:
# Gender
# Female    65899
# Male      63981
# Name: count, dtype: int64

# %%
airline_q['Class'].value_counts()
# Out:
# Class
# Business        62160
# Economy         58309
# Economy Plus     9411
# Name: count, dtype: int64

# %%
airline_q['Satisfaction'].value_counts()
# Out:
# Satisfaction
# Neutral or Dissatisfied    73452
# Satisfied                  56428
# Name: count, dtype: int64

# %% [markdown]
# # Data plot & Analysis

# %%
airline_q['Percentage of quality of service provided']=((airline_q['Departure and Arrival Time Convenience']+airline_q['On-board Service']+airline_q['Seat Comfort']+airline_q['Leg Room Service']+airline_q['Cleanliness']+airline_q['Food and Drink']+airline_q['In-flight Service']+airline_q['In-flight Wifi Service']+airline_q['In-flight Entertainment']+airline_q['Baggage Handling'])/50)*100
airline_q
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
plt.figure(figsize=(10, 10))
#sns.barplot(x=airline_q['Class'], y=['Percentage of quality of service provided'],palette='spring')
plt.xlabel('Class')
plt.ylabel('Percentage of quality of service provided')
plt.title('Percentage of quality of service provided for every calss')
plt.show()

# %% [markdown]
# # save and Documenting the results

# %%
airline_q.to_excel("airline_quality.xlsx",index=False)
